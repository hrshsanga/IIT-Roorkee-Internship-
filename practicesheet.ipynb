# %%
if 5 > 2:
 print('five is greater than two')
if 5 > 2:
  print('five is greater than two')
# Out:
# five is greater than two
# five is greater than two

# %%
print('hello', end=" ")
print('this is Harsh here.')
# Out:
# hello this is Harsh here.

# %%
print('i am', 22, 'years old')
# Out:
# i am 22 years old

# %%
#print("hello")
print('cheers')
# Out:
# cheers

# %%
#this is comment 
print('this should not run')
#"' this is a multiple comment
# Out:
# this should not run

# %%
x = 5
y = 'harsh'
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %%
fruits = ['apple', 'banana']
x, y = fruits
print(y,x)
# Out:
# banana apple

# %%
x = 'awesome'
def myfunction():
    x = 'fantstic'
   
    
myfunction()

print('python is ' + x)
# Out:
# python is awesome
