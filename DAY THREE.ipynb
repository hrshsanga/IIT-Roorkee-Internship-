# %% [markdown]
# # Tasks

# %%
import lib
lib.functionn(2,3)
# Out:
# 2

# %%
#Dice roll simulator
import random
n = random.randint(1,6)
print ('draw number is', n)
# Out:
# draw number is 2

# %%
#TO check if a number is palindrome
i = int(input('enter the number'))
rev = 0
x = i
while i>0:
    rev = (rev*10)+(i%10)
    i = i//10
if x == rev:
    print ('number is pallindrome')
else:
    print('number is not pallindrome')
# Out:
# number is pallindrome

# %%
#fibonnaci series
n = int(input('enter the number:'))
x = 0
y = 1
z = 0
while z <= n:
    print(z)
    x = y
    y = z
    z = x + y
# Out:
# 0
# 1
# 1
# 2
# 3
# 5

# %% [markdown]
# # Practice Sheet

# %%
#Password genrator
import random
import secrets
import string
chars = string.ascii_letters + string.punctuation  + string.digits
password = ''.join(secrets.choice(chars)
for _ in range(int(input('enter the range'))))
print(password)
# Out:
# Wl@=H[3Ow]

# %%
#factorial_calculator
def factorial_iterative(n):
    fact = 1
    for i in range (1, n+1):
        fact *= i
    return fact
def factorial_recursive(n):
    if n == 0 or n == 1:
        return 1
    return n * factorial_recursive(n-1)
print(factorial_recursive(int(input('enter the num'))) )

print(factorial_iterative(int(input('enter the num'))) )
# Out:
# 24
# 24

# %%
#quiz game 
def quiz():
    score = 0

    print("1. Who is developer of python?")
    print("a. Guide van Rossum ",  "b. James Gosling ",  "c. Dennis Ritchie ",  "d. Van Hausng ")
    ans = input('enter a,b,c,d:')
    if ans .lower() == "a":
        print('correct')
        score +=1
    else:
        print('incorrect')
        print('corect ans is', 'a')
    
    print("2. who is the only player to have won 4 medals in the Worldcup history?")
    print("a. pele ",  "b. Miroslav klose ",  "c. Cafu ",  "d. Lotthar Mathaus ")
    ans = input('enter a,b,c,d:')
    if ans .lower() == "b":
        print('correct')
        score +=1
    else:
        print('incorrect')
        print('corect ans is', 'b')
    
    print("3. Which country hosted the first World Cup ?")
    print("a. South Africa ",  "b. Uruguay ",  "c. Qatar ",  "d. Australia ")
    ans = input('enter a,b,c,d:')
    if ans .lower() == "b":
        print('correct')
        score +=1
    else:
        print('incorrect')
        print('corect ans is', 'b')
              
    print("4. What 22/7 is ?")
    print("a. Rational ",  "b. Irational ",  "c. Non terminating rational ",  "d. Terminating Rational ")
    ans = input('enter a,b,c,d:')
    if ans .lower() == "c":
        print('correct')
        score +=1
    else:
        print('incorrect')
        print('corect ans is', 'c')

    print("5. 3.142 is ?")
    print("a. Rational ",  "b. Irational ",  "c. Non terminating rational ",  "d. Terminating Rational ")
    ans = input('enter a,b,c,d:')
    if ans .lower() == "d":
        print('correct')
        score +=1
    else:
        print('incorrect')
        print('corect ans is', 'd')
    
    print("\nyour score =" , score, "/ 5")

# %%
quiz()
# Out:
# 1. Who is developer of python?
# a. Guide van Rossum  b. James Gosling  c. Dennis Ritchie  d. Van Hausng
# correct
# 2. who is the only player to have won 4 medals in the Worldcup history?
# a. pele  b. Miroslav klose  c. Cafu  d. Lotthar Mathaus
# correct
# 3. Which country hosted the first World Cup ?
# a. South Africa  b. Uruguay  c. Qatar  d. Australia
# correct
# 4. What 22/7 is ?
# a. Rational  b. Irational  c. Non terminating rational  d. Terminating Rational
# correct
# 5. 3.142 is ?
# a. Rational  b. Irational  c. Non terminating rational  d. Terminating Rational
# correct
#
# your score = 5 / 5
